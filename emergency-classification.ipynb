# %%
import pandas as pd
import numpy as np 
import glob as glob
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import skimage
from skimage.transform import rotate
from skimage.util import random_noise
from skimage.filters import gaussian
from skimage.transform import AffineTransform, warp
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,InputLayer,Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import Adam
from tqdm import tqdm

# %%
import pandas as pd 
import numpy as np
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
import cv2
import os  
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.layers import Dense,Flatten, Dropout
from tensorflow.keras import losses
from tensorflow.keras import metrics
from tensorflow.keras.optimizers import SGD, Adam

# %%
data=pd.read_csv("/kaggle/input/emergency-vehicles-identification/Emergency_Vehicles/train.csv")
data.head()
# Out:
#   image_names  emergency_or_not
# 0    1503.jpg                 0
# 1    1420.jpg                 0
# 2    1764.jpg                 0
# 3    1356.jpg                 0
# 4    1117.jpg                 0

# %%
data.emergency_or_not.value_counts()
# Out:
# emergency_or_not
# 0    965
# 1    681
# Name: count, dtype: int64

# %%
# create random number generator
seed = 45

# %%
# load images and store it in numpy array

# empty list to store the images
X = []
# iterating over each image
for img_name in data.image_names:
    # loading the image using its name
    img = plt.imread('/kaggle/input/emergency-vehicles-identification/Emergency_Vehicles/train/' + img_name)
    # normalizing the pixel values
    img = img/255
    # saving each image in the list
    X.append(img)
    
# converting the list of images into array
X=np.array(X)

# storing the target variable in separate variable
y = data.emergency_or_not.values

# %%
#shape of original dataset
X.shape
# Out:
# (1646, 224, 224, 3)

# %%
# visualizing images
fig,ax = plt.subplots(nrows=1,ncols=5,figsize=(20,20))
for i in range(5):
    ax[i].imshow(X[i*400])
    ax[i].axis('off')

# %% [markdown]
# ## Creating traing and Validation set

# %%
# creating a training and validation set
X_train, X_valid, y_train, y_valid=train_test_split(X,y,test_size=0.3, random_state=seed)

# %%
#shape of traing and validation dataset
(X_train.shape,y_train.shape),(X_valid.shape,y_valid.shape)
# Out:
# (((1152, 224, 224, 3), (1152,)), ((494, 224, 224, 3), (494,)))

# %% [markdown]
# ## Augmentation of Images

# %%
final_train_data=[]
final_target_data=[]
for i in tqdm(range(X_train.shape[0])):
    #original image
    final_train_data.append(X_train[i])
    #rotating the image
    final_train_data.append(rotate(X_train[i], angle=30, mode = 'edge'))
    #rotating left-right
    final_train_data.append(np.fliplr(X_train[i]))
    #rotating up-down
    final_train_data.append(np.flipud(X_train[i]))
    #add 25% of noise to the image
    final_train_data.append(random_noise(X_train[i],var=0.25))
    for j in range(5):
        final_target_data.append(y_train[i])
# Out:
# 100%|██████████| 1152/1152 [00:15<00:00, 75.43it/s]

# %%
#converting imagers to target array 
final_train=np.array(final_train_data)
final_target_train=np.array(final_target_data)

# %%
# shape of new training set
final_train.shape, final_target_train.shape
# Out:
# ((5760, 224, 224, 3), (5760,))

# %%
# visualizing the augmented images
fig,ax = plt.subplots(nrows=1,ncols=5,figsize=(20,20))
for i in range(5):
    ax[i].imshow(final_train[i+30])
    ax[i].axis('off')

# %%
# converting 3 dimensional image to 1 dimensional image
final_train = final_train.reshape(final_train.shape[0], 224*224*3)
final_train.shape
# Out:
# (5760, 150528)

# %%
# minimum and maximum pixel values of training images
final_train.min(), final_train.max()
# Out:
# (0.0, 1.0)

# %%
# converting 3 dimensional validation image to 1 dimensional image
final_valid = X_valid.reshape(X_valid.shape[0], 224*224*3)
final_valid.shape
# Out:
# (494, 150528)

# %%
# minimum and maximum pixel values of validation images
final_valid.min(), final_valid.max()
# Out:
# (0.0, 1.0)

# %% [markdown]
# # Defining Model Architecture

# %%
# defining the adam optimizer and setting the learning rate as 10^-5
adam = Adam(lr=1e-5)

# %%
# using relu as activation function in hidden layer
model=Sequential()
model.add(InputLayer(input_shape=(224*224*3,)))
model.add(Dense(100, activation='sigmoid'))
model.add(BatchNormalization())
model.add(Dropout(rate=0.5))
model.add(Dense(100, activation='sigmoid'))
model.add(BatchNormalization())
model.add(Dropout(rate=0.4))
model.add(Dense(units=1,activation='sigmoid'))

# %% [markdown]
# # Compling and traing the model

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model_history=model.fit(final_train,final_target_train,epochs=50,batch_size=150,validation_data=(final_valid,y_valid))
# Out:
# Epoch 1/50
# 39/39 [==============================] - 23s 549ms/step - loss: 0.8038 - accuracy: 0.5432 - val_loss: 0.7097 - val_accuracy: 0.5668
# Epoch 2/50
# 39/39 [==============================] - 13s 324ms/step - loss: 0.7402 - accuracy: 0.5674 - val_loss: 0.7030 - val_accuracy: 0.5668
# Epoch 3/50
# 39/39 [==============================] - 13s 346ms/step - loss: 0.7384 - accuracy: 0.5618 - val_loss: 0.6950 - val_accuracy: 0.5668
# Epoch 4/50
# 39/39 [==============================] - 13s 326ms/step - loss: 0.7116 - accuracy: 0.5809 - val_loss: 0.6955 - val_accuracy: 0.5668
# Epoch 5/50
# 39/39 [==============================] - 13s 324ms/step - loss: 0.6938 - accuracy: 0.5878 - val_loss: 0.6993 - val_accuracy: 0.5668
# Epoch 6/50
# 39/39 [==============================] - 13s 333ms/step - loss: 0.6814 - accuracy: 0.5941 - val_loss: 0.6947 - val_accuracy: 0.5668
# Epoch 7/50
# 39/39 [==============================] - 13s 323ms/step - loss: 0.6884 - accuracy: 0.5868 - val_loss: 0.6905 - val_accuracy: 0.5668
# Epoch 8/50
# 39/39 [==============================] - 13s 332ms/step - loss: 0.6761 - accuracy: 0.5920 - val_loss: 0.6933 - val_accuracy: 0.5648
# Epoch 9/50
# 39/39 [==============================] - 13s 322ms/step - loss: 0.6789 - accuracy: 0.5943 - val_loss: 0.6938 - val_accuracy: 0.5648
# Epoch 10/50
# 39/39 [==============================] - 13s 325ms/step - loss: 0.6766 - accuracy: 0.5932 - val_loss: 0.7159 - val_accuracy: 0.5668
# Epoch 11/50
# 39/39 [==============================] - 13s 337ms/step - loss: 0.6858 - accuracy: 0.5903 - val_loss: 0.8089 - val_accuracy: 0.4332
# Epoch 12/50
# 39/39 [==============================] - 13s 321ms/step - loss: 0.6770 - accuracy: 0.5944 - val_loss: 0.7450 - val_accuracy: 0.4332
# Epoch 13/50
# 39/39 [==============================] - 13s 326ms/step - loss: 0.6783 - accuracy: 0.5939 - val_loss: 0.7438 - val_accuracy: 0.4332
# Epoch 14/50
# 39/39 [==============================] - 13s 343ms/step - loss: 0.6770 - accuracy: 0.5950 - val_loss: 0.6987 - val_accuracy: 0.5607
# Epoch 15/50
# 39/39 [==============================] - 13s 323ms/step - loss: 0.6766 - accuracy: 0.5951 - val_loss: 0.7038 - val_accuracy: 0.5607
# Epoch 16/50
# 39/39 [==============================] - 13s 332ms/step - loss: 0.6822 - accuracy: 0.5929 - val_loss: 0.7005 - val_accuracy: 0.5628
# Epoch 17/50
# 39/39 [==============================] - 13s 321ms/step - loss: 0.6838 - accuracy: 0.5866 - val_loss: 0.7010 - val_accuracy: 0.5628
# Epoch 18/50
# 39/39 [==============================] - 13s 321ms/step - loss: 0.6749 - accuracy: 0.5948 - val_loss: 0.7071 - val_accuracy: 0.5628
# Epoch 19/50
# 39/39 [==============================] - 13s 335ms/step - loss: 0.6763 - accuracy: 0.5951 - val_loss: 0.7101 - val_accuracy: 0.5628
# Epoch 20/50
# 39/39 [==============================] - 13s 333ms/step - loss: 0.6758 - accuracy: 0.5938 - val_loss: 0.7162 - val_accuracy: 0.5628
# Epoch 21/50
# 39/39 [==============================] - 13s 334ms/step - loss: 0.6758 - accuracy: 0.5955 - val_loss: 0.7181 - val_accuracy: 0.5628
# Epoch 22/50
# 39/39 [==============================] - 13s 330ms/step - loss: 0.6768 - accuracy: 0.5950 - val_loss: 0.7396 - val_accuracy: 0.5628
# Epoch 23/50
# 39/39 [==============================] - 13s 322ms/step - loss: 0.6759 - accuracy: 0.5951 - val_loss: 0.7420 - val_accuracy: 0.5628
# Epoch 24/50
# 39/39 [==============================] - 14s 361ms/step - loss: 0.6755 - accuracy: 0.5950 - val_loss: 0.7287 - val_accuracy: 0.5628
# Epoch 25/50
# 39/39 [==============================] - 13s 321ms/step - loss: 0.6772 - accuracy: 0.5943 - val_loss: 0.7119 - val_accuracy: 0.5648
# Epoch 26/50
# 39/39 [==============================] - 13s 334ms/step - loss: 0.6752 - accuracy: 0.5951 - val_loss: 0.7153 - val_accuracy: 0.5648
# Epoch 27/50
# 39/39 [==============================] - 13s 321ms/step - loss: 0.6743 - accuracy: 0.5944 - val_loss: 0.7143 - val_accuracy: 0.5648
# Epoch 28/50
# 39/39 [==============================] - 13s 321ms/step - loss: 0.6744 - accuracy: 0.5944 - val_loss: 0.7153 - val_accuracy: 0.5648
# Epoch 29/50
# 39/39 [==============================] - 13s 333ms/step - loss: 0.6755 - accuracy: 0.5946 - val_loss: 0.7102 - val_accuracy: 0.5648
# Epoch 30/50
# 39/39 [==============================] - 13s 321ms/step - loss: 0.6760 - accuracy: 0.5948 - val_loss: 0.7068 - val_accuracy: 0.5648
# Epoch 31/50
# 39/39 [==============================] - 13s 335ms/step - loss: 0.6756 - accuracy: 0.5950 - val_loss: 0.7045 - val_accuracy: 0.5648
# Epoch 32/50
# 39/39 [==============================] - 12s 320ms/step - loss: 0.6758 - accuracy: 0.5944 - val_loss: 0.7159 - val_accuracy: 0.5648
# Epoch 33/50
# 39/39 [==============================] - 12s 320ms/step - loss: 0.6765 - accuracy: 0.5946 - val_loss: 0.7257 - val_accuracy: 0.5648
# Epoch 34/50
# 39/39 [==============================] - 13s 338ms/step - loss: 0.6747 - accuracy: 0.5955 - val_loss: 0.7216 - val_accuracy: 0.5648
# Epoch 35/50
# 39/39 [==============================] - 13s 326ms/step - loss: 0.6744 - accuracy: 0.5948 - val_loss: 0.7208 - val_accuracy: 0.5648
# Epoch 36/50
# 39/39 [==============================] - 13s 333ms/step - loss: 0.6766 - accuracy: 0.5955 - val_loss: 0.7166 - val_accuracy: 0.5648
# Epoch 37/50
# 39/39 [==============================] - 13s 322ms/step - loss: 0.6760 - accuracy: 0.5950 - val_loss: 0.7163 - val_accuracy: 0.5648
# Epoch 38/50
# 39/39 [==============================] - 13s 323ms/step - loss: 0.6751 - accuracy: 0.5955 - val_loss: 0.7151 - val_accuracy: 0.5648
# Epoch 39/50
# 39/39 [==============================] - 13s 335ms/step - loss: 0.6744 - accuracy: 0.5946 - val_loss: 0.7169 - val_accuracy: 0.5628
# Epoch 40/50
# 39/39 [==============================] - 13s 323ms/step - loss: 0.6754 - accuracy: 0.5946 - val_loss: 0.7119 - val_accuracy: 0.5648
# Epoch 41/50
# 39/39 [==============================] - 13s 340ms/step - loss: 0.6757 - accuracy: 0.5943 - val_loss: 0.7124 - val_accuracy: 0.5648
# Epoch 42/50
# 39/39 [==============================] - 13s 321ms/step - loss: 0.6750 - accuracy: 0.5946 - val_loss: 0.7115 - val_accuracy: 0.5648
# Epoch 43/50
# 39/39 [==============================] - 13s 323ms/step - loss: 0.6770 - accuracy: 0.5943 - val_loss: 0.7090 - val_accuracy: 0.5648
# Epoch 44/50
# 39/39 [==============================] - 13s 335ms/step - loss: 0.6752 - accuracy: 0.5951 - val_loss: 0.7079 - val_accuracy: 0.5648
# Epoch 45/50
# 39/39 [==============================] - 13s 328ms/step - loss: 0.6751 - accuracy: 0.5951 - val_loss: 0.7059 - val_accuracy: 0.5648
# Epoch 46/50
# 39/39 [==============================] - 14s 352ms/step - loss: 0.6751 - accuracy: 0.5948 - val_loss: 0.7024 - val_accuracy: 0.5648
# Epoch 47/50
# 39/39 [==============================] - 13s 331ms/step - loss: 0.6759 - accuracy: 0.5957 - val_loss: 0.7009 - val_accuracy: 0.5648
# Epoch 48/50
# 39/39 [==============================] - 30s 792ms/step - loss: 0.6755 - accuracy: 0.5948 - val_loss: 0.7127 - val_accuracy: 0.5648
# Epoch 49/50
# 39/39 [==============================] - 13s 341ms/step - loss: 0.6755 - accuracy: 0.5946 - val_loss: 0.7285 - val_accuracy: 0.5648
# Epoch 50/50
# 39/39 [==============================] - 13s 337ms/step - loss: 0.6763 - accuracy: 0.5946 - val_loss: 0.7238 - val_accuracy: 0.5648

# %%
#model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               15052900
#
#  batch_normalization (Batch  (None, 100)               400
#  Normalization)
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  batch_normalization_1 (Bat  (None, 100)               400
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 15063901 (57.46 MB)
# Trainable params: 15063501 (57.46 MB)
# Non-trainable params: 400 (1.56 KB)
# _________________________________________________________________

# %% [markdown]
# # Evaluating the model

# %%
# Predict probabilities for each class
predicted_probabilities = model.predict(final_valid)

# Get predicted classes by finding the index of the maximum probability for each sample
predicted_classes = np.argmax(predicted_probabilities, axis=1)
# Out:
# 16/16 [==============================] - 1s 28ms/step

# %%
# accuracy on validation set
print('Accuracy on validation set:', accuracy_score(y_valid, predicted_classes), '%')
# Out:
# Accuracy on validation set: 0.5668016194331984 %

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model acuuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
